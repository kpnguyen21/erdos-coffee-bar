# %% [markdown]
# # University of Houston data

# %% [markdown]
# Create data frame using data from [The University of Houston website](https://www.uh.edu/ir/reports/statistical-handbook/student-enrollment/)

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Student data

# %%
semester = []
for i in range(2014, 2025):
    semester.append('Spring ' + str(i))
    semester.append('Summer ' + str(i))
    semester.append('Fall ' + str(i))

len(semester)
# Out:
# 33

# %%
# enrollment
total_enrollment = [37538, 14797, 40914, #2014
                    39032, 14216, 42704, #2015
                    40285, 15672, 43774, #2016
                    41411, 15406, 45364, #2017
                    42360, 16376, 46324, #2018
                    42882, 16367, 46148, #2019
                    42516, 20190, 47090, #2020
                    43432, 16959, 47031, #2021
                    43488, 16616, 46700, #2022
                    43014, 15266, 46676, #2023
                    43576, 16379, 47980 #2024
                   ]
male = [18917, 7198, 20730, #2014
        19774, 6747, 21695, #2015
        20423, 7735, 22251, #2016
        20945, 7274, 22756, #2017
        21288, 7565, 22958, #2018
        21185, 7473, 22683, #2019
        20769, 9215, 22864, #2020
        21089, 7639, 22646, #2021
        20888, 7652, 22359, #2022
        20522, 7073, 22339, #2023
        20851, 7738, 22942 #2024
       ]
female = [18621, 7599, 20184, #2014
          19258, 7469, 21009, #2015
          19862, 7937, 21523, #2016
          20466, 8132, 22608, #2017
          21072, 8811, 23366, #2018
          21697, 8894, 23465, #2019
          21747, 10975, 24226, #2020
          22343, 9320, 24385, #2021
          22600, 8964, 24341, #2022
          22492, 8193, 24337, #2023
          22725, 8641, 25038 #2024
         ]
undergrad = [28535, 10463, 31722, #2014
             30080, 10915, 33404, #2015
             31374, 11611, 34688, #2016
             32502, 11999, 36088, #2017
             33683, 12537, 37369, #2018
             34524, 12626, 37689, #2019
             34466, 15496, 38213, #2020
             34797, 13002, 37833,#2021
             34588, 12114, 37282, #2022
             34088, 11499, 37356, #2023
             34621, 12329, 38673 #2024
            ]
postbac = [1234, 580, 1325, #2014
           1347, 564, 1426, #2015
           1425, 621, 1310, #2016
           1303, 646, 1246, #2017
           1131, 536, 1121, #2018
           1041, 471, 1041, #2019
           977, 544, 1077, #2020
           1002, 442, 866, #2021
           774, 346, 760, #2022
           700, 333, 708, #2023
           700, 308, 679 #2024
          ]
master = [4190, 1803, 4111, #2014
          3936, 1629, 4064, #2015
          3852, 1579, 3985, #2016
          3927, 1646, 4174, #2017
          3819, 1758, 3934, #2018
          3564, 1720, 3579, #2019
          3379, 1747, 3922, #2020
          3930, 1860, 4427, #2021
          4396, 2090, 4750, #2022
          4464, 1774, 4608, #2023
          4374, 1708, 4524 #2024
         ]
doctor = [2039, 1233, 2179, #2014
          2136, 460, 2232, #2015
          2096, 1198, 2199, #2016
          2122, 397, 2249, #2017
          2143, 825, 2295, #2018
          2181, 758, 2285, #2019
          2178, 1555, 2276, #2020
          2155, 877, 2262, #2021
          2145, 1341, 2189, #2022
          2083, 916, 2230, #2023
          2148, 1342, 2269 #2024
         ]
professional = [1540, 718, 1577, #2014
                1533, 648, 1578, #2015
                1538, 663, 1592, #2016
                1557, 718, 1607, #2017
                1584, 720, 1605, #2018
                1572, 792, 1554, #2019
                1516, 848, 1602, #2020
                1548, 778, 1643, #2021
                1585, 725, 1719, #2022
                1679, 744, 1774, #2023
                1733, 692, 1835 #2024
               ]

# %%
# average age
age_undergrad_male = [23.4, 24.1, 23.1, #2014
                    23.3, 23.8, 23, #2015
                    23.2, 23.7, 22.9, #2016
                    23.1, 23.6, 22.7, #2017
                    22.9, 23.4, 22.6, #2018
                    22.8, 23.3, 22.4, #2019
                    22.6, 23.1, 22.4, #2020
                    22.7, 23.1, 22.3, #2021
                    22.6, 23, 22.2, #2022
                    22.5, 22.9, 22.2, #2023
                    22.4, 23, 22 #2024
                     ]
age_undergrad_female = [23.1, 23.5, 22.8, #2014
                    23, 23.4, 22.7, #2015
                    22.9, 23.2, 22.5, #2016
                    22.8, 23, 22.4, #2017
                    22.6, 23.1, 22.3, #2018
                    22.6, 23, 22.2, #2019
                    22.4, 22.8, 22.2, #2020
                    22.4, 22.7, 22, #2021
                    22.2, 22.7, 21.9, #2022
                    22.1, 22.8, 21.8, #2023
                    22.1, 22.7, 21.7 #2024
                       ]
age_postbac_male = [31, 30.5, 31.3, #2014
                    30.9, 30.9, 30.9, #2015
                    30.8, 30.9, 31.1, #2016
                    30.8, 30.5, 30.8, #2017
                    31.3, 30.5, 31.1, #2018
                    31.2, 30.1, 31, #2019
                    31.4, 31.4, 30.4, #2020
                    30.6, 31.6, 30.7, #2021
                    30.7, 29.2, 30.5, #2022
                    30.5, 29.5, 30, #2023
                    30.5, 28.7, 29.7 #2024
                   ]
age_postbac_female = [30.3, 29.4, 30, #2014
                    30.1, 29.7, 30.1, #2015
                    30, 29.6, 30.7, #2016
                    30.7, 30.4, 30.2, #2017
                    30.4, 30.3, 30.2, #2018
                    30.2, 29.4, 30.2, #2019
                    30.2, 30, 30.3, #2020
                    30.5, 29.6, 30.7, #2021
                    30.1, 29.2, 29.2, #2022
                    29.6, 29.6, 30.1, #2023
                    29.5, 28.6, 29.7 #2024
                     ]
age_master_male = [30.1, 31.3, 29.7, #2014
                   29.3, 30.5, 29.1, #2015
                   29.3, 30.9, 29.1, #2016
                   29.5, 30.6, 29.1, #2017
                   29.3, 30.3, 29.3, #2018
                   29.5, 30.1, 29.3, #2019
                   29.4, 30.6, 29.6, #2020
                   29.8, 30.8, 29.6, #2021
                   29.6, 30.5, 29.3, #2022
                   29.5, 30.9, 29.3, #2023
                   29.4, 30.5, 29.2 #2024
                  ]
age_master_female = [29.7, 30.4, 29.5, #2014
                    29.5, 30.2, 29.4, #2015
                    29.5, 30.3, 29.3, #2016
                    29.4, 29.8, 29.3, #2017
                    29.6, 30.1, 29.8, #2018
                    30.1, 30.8, 29.6, #2019
                    29.9, 30.6, 29.8, #2020
                    29.9, 30.6, 29.8, #2021
                    30, 30.9, 29.8, #2022
                    29.8, 31, 29.7, #2023
                    29.8, 30.7, 29.4 #2024
                    ]
age_doctor_male = [31, 30.3, 30.6, #2014
                    30.9, 34.2, 30.7, #2015
                    30.7, 29.4, 30.5, #2016
                    30.6, 32.9, 30.5, #2017
                    30.8, 31, 30.7, #2018
                    30.9, 31.5, 31, #2019
                    31.1, 30.4, 31.1, #2020
                    31.3, 31, 31.2, #2021
                    31.5, 30.5, 31.3, #2022
                    31.5, 31.1, 31.5, #2023
                    31.6, 31, 31.6 #2024
                  ]
age_doctor_female = [32, 31.4, 31.7, #2014
                    31.9, 35, 31.8, #2015
                    32, 30.5, 31.8, #2016
                    32.1, 33.2, 32.1, #2017
                    32.4, 32.7, 32.4, #2018
                    32.6, 33.2, 33.1, #2019
                    33.3, 32.6, 33.3, #2020
                    33.6, 33.8, 33.6, #2021
                    33.6, 32.7, 33.2, #2022
                    33, 32.8, 33, #2023
                    33.2, 31.7, 32.9 #2024
                    ]
age_special_profession_male = [27.9, 28.8, 27.4, #2014
                                27.6, 28.4, 27.5, #2015
                                27.9, 29.4, 27.6, #2016
                                27.9, 29.3, 27.6, #2017
                                28, 29, 27.8, #2018
                                28.1, 29.1, 27.9, #2019
                                28.2, 29.2, 27.6, #2020
                                27.8, 29, 27.7, #2021
                                27.9, 30.3, 27.7, #2022
                                28.1, 29.5, 27.2, #2023
                                27.4, 29.3, 26.5 #2024
                    ] 
age_special_profession_female =[26.8, 26.6, 26.2, #2014
                                26.5, 26.4, 26, #2015
                                26.4, 27, 26.3, #2016
                                26.7, 27.2, 26.6, #2017
                                27, 28.1, 26.6, #2018
                                27.1, 27.8, 26.6, #2019
                                27, 27.8, 26.5, #2020
                                26.8, 28.4, 26.5, #2021
                                26.9, 27.6, 26.3, #2022
                                26.5, 27.5, 25.9, #2023
                                26.1, 27.2, 25.5 #2024
                    ]
age_opt_male = [26.4, 27.2, 26.2, #2014
                26.6, 27, 25.9, #2015
                26.3, 26.6, 25.9, #2016
                26.3, 26.6, 26.1, #2017
                26.5, 26.7, 26.2, #2018
                26.6, 27.3, 26.3, #2019
                26.7, 27.4, 26.3, #2020
                26.5, 27.1, 25.8, #2021
                26.3, 27, 25.5, #2022
                25.9, 25.9, 25.5, #2023
                25.9, 26.2, 26 #2024
               ]
age_opt_female = [25.5, 25.7, 25, #2014
                    25.4, 26.1, 25.1, #2015
                    25.4, 25.7, 24.9, #2016
                    25.2, 25.9, 25, #2017
                    25.4, 25.7, 25, #2018
                    25.4, 25.7, 24.9, #2019
                    25.3, 25.6, 24.8, #2020
                    25.2, 25.4, 24.8, #2021
                    25.3, 25.5, 24.8, #2022
                    25.2, 25.8, 24.9, #2023
                    25.3, 25.7, 24.7 #2024
                 ]
age_pharm_male = [26.4, 26.9, 26, #2014
                    26.4, 26.1, 25.2, #2015
                    25.4, 26.2, 25.4, #2016
                    25.8, 26, 25.5, #2017
                    25.9, 26.4, 25.9, #2018
                    26.3, 26.6, 26, #2019
                    26.5, 26.4, 26.3, #2020
                    26.7, 26.8, 26.7, #2021
                    27.1, 26.4, 26.6, #2022
                    27.2, 27, 26.4, #2023
                    26.8, 26.5, 26.1 #2024
                 ]
age_pharm_female = [25.1, 25.6, 24.7, #2014
                    25.1, 25.2, 25, #2015
                    25.3, 25.5, 25.1, #2016
                    25.5, 25.8, 25.1, #2017
                    25.5, 26.1, 25.4, #2018
                    25.8, 25.8, 25.6, #2019
                    25.9, 25.9, 25.7, #2020
                    26.1, 26, 25.6, #2021
                    26, 25.8, 25.8, #2022
                    26, 26.1, 25.7, #2023
                    26, 227, 25.5 #2024
                   ]

## Starting in 2020, UH has a medicine program. However, it is in a different campus, so we do not include our coffee bar analysis.

# %%
# age counts
age_undergrad_male_cnt = [14360, 5077, 16060, #2014
                        15252, 5262, 17045, #2015
                        15966, 5808, 17765, #2016
                        16583, 5816, 18244, #2017
                        17104, 5955, 18763, #2018
                        17304, 6005, 18837, #2019
                        17155, 7252, 18875, #2020
                        17173, 6110, 18479, #2021
                        16863, 5711, 17965, #2022
                        16384, 5498, 17962, #2023
                        16642, 5879, 18603 #2024
                    ]
age_undergrad_female_cnt = [14175, 5386, 15662, #2014
                            14828, 5653, 16359, #2015
                            15408, 5803, 16923, #2016
                            15919, 6183, 17844, #2017
                            16579, 6582, 18606, #2018
                            17220, 6621, 18852, #2019
                            17311, 8244, 19338, #2020
                            17624, 6892, 19354, #2021
                            17725, 6403, 19317, #2022
                            17704, 6011, 19394, #2023
                            17979, 6450, 20070 #2024
                    ]
age_postbac_male_cnt = [633, 267, 694, #2014
                        725, 275, 721, #2015
                        708, 284, 646, #2016
                        618, 280, 573, #2017
                        525, 217, 508, #2018
                        484, 197, 454, #2019
                        437, 216, 478, #2020
                        459, 174, 400, #2021
                        363, 138, 374, #2022
                        323, 143, 320, #2023
                        312, 133, 291 #2024
                    ]
age_postbac_female_cnt = [601, 313, 631, #2014
                        622, 289, 705, #2015
                        717, 337, 664, #2016
                        685, 366, 673, #2017
                        606, 319, 613, #2018
                        557, 274, 587, #2019
                        540, 328, 599, #2020
                        543, 268, 466, #2021
                        411, 208, 386, #2022
                        377, 190, 388, #2023
                        388, 175, 388 #2024
                    ]
age_master_male_cnt = [2154, 890, 2112, #2014
                    1983, 763, 2028, #2015
                    1951, 694, 1989, #2016
                    1937, 715, 2017, #2017
                    1828, 697, 1822, #2018
                    1603, 646, 1581, #2019
                    1442, 595, 1689, #2020
                    1716, 680, 1952, #2021
                    1959, 833, 2234, #2022
                    2110, 743, 2213, #2023
                    2107, 740, 2155 #2024
                    ]
age_master_female_cnt = [2036, 913, 1999, #2014
                    1953, 866, 2036, #2015
                    1901, 885, 1996, #2016
                    1990, 931, 2157, #2017
                    1991, 1061, 2112, #2018
                    1961, 1074, 1998, #2019
                    1937, 1152, 2233, #2020
                    2214, 1180, 2475, #2021
                    2437, 1257, 2516, #2022
                    2354, 1031, 2395, #2023
                    2267, 968, 2369 #2024
                    ]
age_doctor_male_cnt = [1082, 648, 1174, #2014
                    1145, 183, 1212, #2015
                    1128, 671, 1170, #2016
                    1142, 152, 1219, #2017
                    1150, 406, 1213, #2018
                    1157, 336, 1199, #2019
                    1137, 825, 1178, #2020
                    1126, 392, 1172, #2021
                    1096, 720, 1127, #2022
                    1071, 433, 1183, #2023
                    1147, 746, 1216 #2024
                    ]
age_doctor_female_cnt = [957, 585, 1005, #2014
                    991, 277, 1020, #2015
                    968, 527, 1029, #2016
                    980, 245, 1030, #2017
                    993, 419, 1082, #2018
                    1024, 422, 1086, #2019
                    1041, 730, 1098, #2020
                    1029, 485, 1090, #2021
                    1049, 621, 1062, #2022
                    1012, 483, 1047, #2023
                    1001, 596, 1053 #2024
                    ]
age_special_profession_male_cnt = [383, 154, 380, #2014
                                    360, 118, 378, #2015
                                    365, 124, 377, #2016
                                    366, 132, 384, #2017
                                    366, 132, 355, #2018
                                    343, 110, 334, #2019
                                    317, 132, 326, #2020
                                    308, 105, 343, #2021
                                    320, 86, 351, #2022
                                    335, 104, 354, #2023
                                    340, 78, 360 #2024
                    ] 
age_special_profession_female_cnt =[321, 121, 342, #2014
                                    329, 112, 339, #2015
                                    316, 104, 327, #2016
                                    318, 100, 320, #2017
                                    319, 111, 343, #2018
                                    337, 119, 341, #2019
                                    333, 153, 354, #2020
                                    342, 121, 378, #2021
                                    370, 126, 411, #2022
                                    401, 134, 435, #2023
                                    428, 110, 449 #2024
                    ]
age_opt_male_cnt = [142, 70, 144, #2014
                    143, 66, 140, #2015
                    138, 70, 136, #2016
                    135, 73, 140, #2017
                    135, 63, 129, #2018
                    125, 60, 123, #2019
                    122, 64, 138, #2020
                    129, 66, 132, #2021
                    124, 59, 129, #2022
                    124, 64, 128, #2023
                    127, 68, 124 #2024
                    ]
age_opt_female_cnt = [253, 129, 252, #2014
                    245, 120, 253, #2015
                    253, 122, 256, #2016
                    251, 135, 266, #2017
                    263, 131, 269, #2018
                    260, 128, 267, #2019
                    255, 122, 252, #2020
                    245, 130, 248, #2021
                    241, 117, 244, #2022
                    241, 116, 250, #2023
                    239, 115, 256 #2024
                    ]
age_pharm_male_cnt = [163, 92, 166, #2014
                    166, 80, 171, #2015
                    167, 84, 168, #2016
                    164, 106, 179, #2017
                    180, 95, 168, #2018
                    169, 119, 155, #2019
                    159, 131, 169, #2020
                    167, 112, 147, #2021
                    142, 105, 136, #2022
                    132, 88, 121, #2023
                    119, 94, 131 #2024
                    ]
age_pharm_female_cnt = [278, 152, 293, #2014
                        290, 152, 297, #2015
                        299, 159, 328, #2016
                        323, 172, 318, #2017
                        321, 188, 341, #2018
                        338, 256, 334, #2019
                        330, 246, 333, #2020
                        327, 244, 335, #2021
                        328, 232, 328, #2022
                        326, 238, 315, #2023
                        315, 227, 309 #2024
                    ]

# %%
# race
white = [11478, 4625, 11855, #2014 -> white majority
         11211, 4444, 11791, #2015
         11129, 4610, 12760, #2016
         11080, 4437, 11629, #2017 -> hispanic majority
         10884, 4473, 11417, #2018
         10557, 4306, 10924, #2019
         10078, 4984, 10831, #2020
         10011, 4055, 10182, #2021 -> asian american surpasses White
         9332, 3573, 9351, #2022
         8592, 3174, 3783, #2023
         8189, 3156, 8551 #2024
        ]
hispanic = [9686, 3590, 10994, #2014
            10530, 3818, 11743, #2015
            11118, 3983, 11730, #2016
            12084, 4470, 13873, #2017
            13042, 4758, 14725, #2018
            13646, 5093, 14963, #2019
            13661, 6013, 15639, #2020
            14257, 5354, 15654, #2021
            14305, 5022, 15524, #2022
            14218, 4710, 15666, #2023
            14574, 5221, 16337 #2024
           ]
asian_american = [7338, 2915, 8215, #2014
                  7956, 2989, 8802, #2015
                  8284, 3324, 9076, #2016
                  8638, 3374, 9415, #2017
                  8757, 3499, 9666, #2018
                  9021, 3503, 9778, #2019
                  9137, 4541, 10155, #2020
                  9486, 3914, 10377, #2021
                  9635, 3480, 10308, #2022
                  9616, 3209, 10212, #2023
                  9475, 3335, 10223 #2024
            ]
african_american = [3889, 1486, 4173, #2014
                    3885, 1390, 4271, #2015
                    3959, 1553, 4241, #2016
                    3974, 1494, 4401, #2017
                    4090, 1643, 4511, #2018
                    4140, 1641, 4562, #2019
                    4158, 2015, 4811, #2020
                    4402, 1812, 5034, #2021
                    4640, 1809, 5080, #2022
                    4588, 1677, 5204, #2023
                    4873, 1747, 5690 #2024
            ]
international = [3724, 1611, 4025, #2014
                3860, 964, 4119, #2015
                3880, 1434, 3995, #2016
                3714, 862, 3865, #2017
                3511, 1108, 3675, #2018
                3333, 970, 3464, #2019
                3197, 1618, 3273, #2020
                3137, 997, 3619, #2021
                3612, 2009, 4387, #2022
                4121, 1814, 4718, #2023
                4514, 2216, 5015 #2024
            ]
others = [1423, 570, 1652, #2014
          1590, 611, 1978, #2015
          1915, 768, 1972, #2016
          1921, 769, 2181, #2017
          2076, 895, 2330, #2018
          2185, 854, 2457, #2019
          2285, 1019, 2381, #2020
          2139, 827, 2165, #2021
          1964, 723, 2050, #2022
          1879, 682, 2093, #2023
          1951, 704, 2164 #2024
             ]

# %% [markdown]
# ## Create dataframes

# %%
c = ['Semester', 'Total_enrollment', 'Male', 'Female', 'Undergrad', 'Postbac', 'Master', 'Doctoral', 'Professional',
         'Age_Undergrad_Male', 'Age_Undergrad_Female', 'Age_Postbac_Male', 'Age_Postbac_Female', 'Age_Master_Male', 'Age_Master_Female',
         'Age_Doctor_Male', 'Age_Doctor_Female', 'Age_Profession_Male', 'Age_Profession_Female', 
         'Age_Opt_Male', 'Age_Opt_Female', 'Age_Pharm_Male', 'Age_Pharm_Female',
         'Undergrad_Male', 'Undergrad_Female', 'Postbac_Male', 'Postbac_Female', 'Mater_Male', 'Master_Female',
         'Doctor_Male', 'Doctor_Female', 'Profession_Male', 'Profession_Female', 
         'Opt_Male', 'Opt_Female', 'Pharm_Male', 'Pharm_Female',
         'White', 'Hispanic', 'Asian_American', 'African_American', 'International', 'Others']

# %%
student = pd.DataFrame(list(zip(semester, total_enrollment, male, female, undergrad, postbac, master, doctor, professional, 
age_undergrad_male, age_undergrad_female, age_postbac_male, age_postbac_female, age_master_male, age_master_female,
age_doctor_male, age_doctor_female, age_special_profession_male, age_special_profession_female,
age_opt_male, age_opt_female, age_pharm_male, age_pharm_female, 
age_undergrad_male_cnt, age_undergrad_female_cnt, age_postbac_male_cnt, age_postbac_female_cnt, 
age_master_male_cnt, age_master_female_cnt,
age_doctor_male_cnt, age_doctor_female_cnt, age_special_profession_male_cnt, age_special_profession_female_cnt,
age_opt_male_cnt, age_opt_female_cnt, age_pharm_male_cnt, age_pharm_female_cnt, 
white, hispanic, asian_american, african_american, international, others)), columns = c)

# %%
student.head()
# Out:
#       Semester  Total_enrollment   Male  Female  Undergrad  Postbac  Master  \
# 0  Spring 2014             37538  18917   18621      28535     1234    4190
# 1  Summer 2014             14797   7198    7599      10463      580    1803
# 2    Fall 2014             40914  20730   20184      31722     1325    4111
# 3  Spring 2015             39032  19774   19258      30080     1347    3936
# 4  Summer 2015             14216   6747    7469      10915      564    1629
#
#    Doctoral  Professional  Age_Undergrad_Male  ...  Opt_Male  Opt_Female  \
# 0      2039          1540                23.4  ...       142         253
# 1      1233           718                24.1  ...        70         129
# 2      2179          1577                23.1  ...       144         252
# 3      2136          1533                23.3  ...       143         245
# 4       460           648                23.8  ...        66         120
#
#    Pharm_Male  Pharm_Female  White  Hispanic  Asian_American  \
# ...

# %%
student.to_csv('Data/students.csv', index=False)

# %% [markdown]
# ## Plotting

# %%
[student.Semester.iloc[x] for x in range(0, len(student), 3)]
# Out:
# ['Spring 2014',
#  'Spring 2015',
#  'Spring 2016',
#  'Spring 2017',
#  'Spring 2018',
#  'Spring 2019',
#  'Spring 2020',
#  'Spring 2021',
#  'Spring 2022',
#  'Spring 2023',
#  'Spring 2024']

# %%
plt.figure(figsize=(15, 10))
plt.plot(student.Semester, student.Male, label = 'Male')
plt.plot(student.Semester, student.Female, label = 'Female')
plt.xticks([student.Semester.iloc[x] for x in range(0, len(student), 3)])
plt.legend()
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.plot(student.Semester, student.White, label = 'White')
plt.plot(student.Semester, student.Hispanic, label = 'Hispanic')
plt.plot(student.Semester, student.Asian_American, label = 'Asian American')
plt.plot(student.Semester, student.African_American, label = 'African American')
plt.plot(student.Semester, student.International, label = 'International')
plt.plot(student.Semester, student.Others, label = 'Others')
plt.xticks([student.Semester.iloc[x] for x in range(0, len(student), 3)])
plt.legend()
plt.show()

# %% [markdown]
# ## Housing capacity

# %% [markdown]
# Create data frame using data from [Housing Bed Capacity](https://www.uh.edu/housing/about/assessment-and-strategic-planning/reports/shrl-student-success-report.pdf/)
#
# 2007: 3,924 beds \
# 2010: 4,980 beds \
# 2011: 6,075 beds \
# 2013: 8,008 beds \
# 2020: 8,397 beds
#
# [New dorm residence hall in 2027](https://www.statesman.com/story/news/state/2024/08/26/university-of-houston-new-dorm-residence-hall-freshman-campus-students-college-record-enrollment/74951846007/): By 2027, there will be 10,000 beds.

# %% [markdown]
# ## Alcohol consumption

# %% [markdown]
# [Alcohol consumption by capita](https://www.cia.gov/the-world-factbook/field/alcohol-consumption-per-capita/country-comparison/)
#
# [Alcohol consumption by age](https://www.statista.com/statistics/354265/current-binge-heavy-alcohol-use-among-persons-in-the-us-by-age/)
#
# [Alcohol consumption by race](https://pmc.ncbi.nlm.nih.gov/articles/PMC3887493/)

# %% [markdown]
# ## International Students

# %%
China = [897, 469, 934, # 2014 
        837, 187, 888, # 2015
        853, 377, 854, # 2016
        786, 147, 789, # 2017
        711, 207, 760, # 2018
        692, 187, 676, # 2019
        623, 393, 613, # 2020
        570, 188, 649, # 2021
        589, 590, 752, # 2022
        679, 680, 835, # 2023
        781, 803, 959 # 2024
        ]

# %%
India = [791, 290, 917, # 2014 
        917, 191, 961, # 2015
        875, 237, 914, # 2016
        809, 158, 885, # 2017
        774, 224, 762, # 2018
        634, 174, 645, # 2019
        590, 253, 542, # 2020
        578, 140, 829, # 2021
        989, 528, 1390, # 2022
        1371, 379, 1437, # 2023
        1408, 391, 1465 # 2024
        ]

# %%
Vietnam = [340, 78, 320, # 2014 
            306, 49, 325, # 2015
            312, 68, 322, # 2016
            324, 68, 360, # 2017
            344, 79, 385, # 2018
            376, 82, 435, # 2019
            396, 142, 436, # 2020
            398, 113, 402, # 2021
            370, 117, 389, # 2022
            353, 124, 360, # 2023
            297, 98, 311 # 2024
        ]

# %%
Nigeria = [131, 46, 149, # 2014 
            154, 49, 158, # 2015
            162, 47, 143, # 2016
            139, 41, 145, # 2017
            133, 40, 133, # 2018
            127, 36, 135, # 2019
            124, 55, 144, # 2020
            129, 36, 147, # 2021
            152, 62, 176, # 2022
            168, 57, 191, # 2023
            194, 78, 221 # 2024
        ]

# %%
Saudi_Arabia = [100, 49, 138, # 2014 
                141, 91, 131, # 2015
                131, 76, 138, # 2016
                128, 75, 128, # 2017
                121, 54, 85, # 2018
                81, 41, np.nan, # 2019
                np.nan, np.nan, np.nan, # 2020
                np.nan, np.nan, np.nan, # 2021
                np.nan, np.nan, np.nan, # 2022
                np.nan, np.nan, np.nan, # 2023
                np.nan, np.nan, np.nan # 2024
        ]

# %%
South_Korea = [114, 56, 131, # 2014 
                119, 21, 128, # 2015
                118, 42, 122, # 2016
                123, 20, 123, # 2017
                124, 37, 120, # 2018
                114, 32, 103, # 2019
                89, 48, 87, # 2020
                78, 30, 84, # 2021
                73, 28, 69, # 2022
                62, 23, np.nan, # 2023
                np.nan, np.nan, np.nan # 2024
        ]

# %%
Iran = [101, 74, 124, # 2014 
        140, np.nan, 154, # 2015
        150, 93, 138, # 2016
        143, np.nan, 130, # 2017
        124, 39, 125, # 2018
        124, 37, 126, # 2019
        124, 99, 110, # 2020
        98, 38, 99, # 2021
        105, 80, 116, # 2022
        118, 45, 125, # 2023
        122, 88, 125 # 2024
        ]

# %%
Mexico = [102, np.nan, 101, # 2014 
        94, 29, 116, # 2015
        109, 33, 121, # 2016
        99, np.nan, 97, # 2017
        84, np.nan, 109, # 2018
        100, 31, 108, # 2019
        102, 42, 124, # 2020
        118, 30, 119, # 2021
        118, 34, 150, # 2022
        128, 37, 166, # 2023
        147, 51, 162 # 2024
        ]

# %%
Venezuela = [90, np.nan, 96, # 2014 
            96, 24, 94, # 2015
            95, 33, 89, # 2016
            89, 36, 88, # 2017
            81, 28, 81, # 2018
            76, np.nan, 79, # 2019
            79, np.nan, 89, # 2020
            87, 30, 91, # 2021
            80, 35, 83, # 2022
            59, np.nan, 93, # 2023
            95, np.nan, 129 # 2024
        ]

# %%
Canada = [72, 34, 81, # 2014 
        79, 20, 81, # 2015
        np.nan, np.nan, np.nan, # 2016
        np.nan, 29, np.nan, # 2017
        np.nan, np.nan, np.nan, # 2018
        np.nan, 25, np.nan, # 2019
        np.nan, np.nan, np.nan, # 2020
        np.nan, np.nan, np.nan, # 2021
        np.nan, np.nan, np.nan, # 2022
        np.nan, 22, 80, # 2023
        81, np.nan, 98 # 2024
        ]

# %%
Taiwan = [np.nan, 46, np.nan, # 2014 
        np.nan, np.nan, np.nan, # 2015
        np.nan, np.nan, np.nan, # 2016
        np.nan, np.nan, np.nan, # 2017
        np.nan, np.nan, np.nan, # 2018
        np.nan, np.nan, 74, # 2019
        66, 34, np.nan, # 2020
        np.nan, np.nan, np.nan, # 2021
        np.nan, np.nan, np.nan, # 2022
        np.nan, np.nan, np.nan, # 2023
        np.nan, np.nan, np.nan # 2024
         ]

# %%
Turkey = [np.nan, 30, np.nan, # 2014 
        np.nan, np.nan, np.nan, # 2015
        np.nan, np.nan, np.nan, # 2016
        np.nan, np.nan, np.nan, # 2017
        np.nan, np.nan, np.nan, # 2018
        np.nan, np.nan, np.nan, # 2019
        np.nan, np.nan, np.nan, # 2020
        np.nan, np.nan, np.nan, # 2021
        np.nan, np.nan, np.nan, # 2022
        np.nan, np.nan, np.nan, # 2023
        np.nan, np.nan, np.nan # 2024
         ]

# %%
Peru = [np.nan, np.nan, np.nan, # 2014 
        np.nan, 24, np.nan, # 2015
        np.nan, np.nan, np.nan, # 2016
        np.nan, 21, np.nan, # 2017
        np.nan, np.nan, np.nan, # 2018
        np.nan, np.nan, np.nan, # 2019
        np.nan, np.nan, np.nan, # 2020
        np.nan, np.nan, np.nan, # 2021
        np.nan, np.nan, np.nan, # 2022
        np.nan, np.nan, np.nan, # 2023
        np.nan, np.nan, np.nan # 2024
         ]

# %%
Pakistan = [np.nan, np.nan, np.nan, # 2014 
        np.nan, 24, np.nan, # 2015
        73, np.nan, 88, # 2016
        84, 25, 96, # 2017
        87, 25, 104, # 2018
        90, np.nan, 94, # 2019
        87, np.nan, 93, # 2020
        99, 26, 117, # 2021
        118, 55, 139, # 2022
        136, 46, 170, # 2023
        172, 84, 198 # 2024
         ]

# %%
Nepal = [np.nan, np.nan, np.nan, # 2014 
        np.nan, np.nan, np.nan, # 2015
        np.nan, 30, np.nan, # 2016
        np.nan, np.nan, np.nan, # 2017
        np.nan, np.nan, np.nan, # 2018
        np.nan, np.nan, np.nan, # 2019
        np.nan, 44, np.nan, # 2020
        np.nan, np.nan, np.nan, # 2021
        np.nan, np.nan, np.nan, # 2022
        np.nan, np.nan, np.nan, # 2023
        np.nan, 40, np.nan # 2024
         ]

# %%
Ukraine = [np.nan, np.nan, np.nan, # 2014 
        np.nan, np.nan, np.nan, # 2015
        np.nan, np.nan, np.nan, # 2016
        np.nan, np.nan, np.nan, # 2017
        np.nan, 25, np.nan, # 2018
        np.nan, 29, np.nan, # 2019
        np.nan, np.nan, np.nan, # 2020
        np.nan, 26, np.nan, # 2021
        np.nan, np.nan, np.nan, # 2022
        np.nan, np.nan, np.nan, # 2023
        np.nan, np.nan, np.nan # 2024
         ]

# %%
Bangladesh = [np.nan, np.nan, np.nan, # 2014 
        np.nan, np.nan, np.nan, # 2015
        np.nan, np.nan, np.nan, # 2016
        np.nan, np.nan, np.nan, # 2017
        np.nan, np.nan, np.nan, # 2018
        np.nan, np.nan, np.nan, # 2019
        np.nan, 46, 76, # 2020
        78, np.nan, 103, # 2021
        100, 70, 106, # 2022
        107, 46, 141, # 2023
        141, 95, 166 # 2024
         ]

# %%
Sri_Lanka = [np.nan, np.nan, np.nan, # 2014 
        np.nan, np.nan, np.nan, # 2015
        np.nan, np.nan, np.nan, # 2016
        np.nan, np.nan, np.nan, # 2017
        np.nan, np.nan, np.nan, # 2018
        np.nan, np.nan, np.nan, # 2019
        np.nan, np.nan, np.nan, # 2020
        np.nan, np.nan, np.nan, # 2021
        np.nan, np.nan, np.nan, # 2022
        np.nan, np.nan, np.nan, # 2023
        np.nan, 32, np.nan # 2024
         ]

# %%
c2 = ['Semester', 'China', 'India', 'Vietnam', 'Nigeria', 'Saudi_Arabia', 'South_Korea', 'Iran', 'Mexico', 'Venezuela', 'Canada', 'Taiwan', 'Turkey',
'Peru', 'Pakistan', 'Nepal', 'Ukraine', 'Bangladesh', 'Sri_Lanka']

# %%
international_students = pd.DataFrame(list(zip(semester, China, India, Vietnam, Nigeria, Saudi_Arabia, South_Korea, Iran, Mexico, Venezuela, Canada, Taiwan, Turkey,
Peru, Pakistan, Nepal, Ukraine, Bangladesh, Sri_Lanka)), columns = c2)

# %%
international_students
# Out:
#        Semester  China  India  Vietnam  Nigeria  Saudi_Arabia  South_Korea  \
# 0   Spring 2014    897    791      340      131         100.0        114.0
# 1   Summer 2014    469    290       78       46          49.0         56.0
# 2     Fall 2014    934    917      320      149         138.0        131.0
# 3   Spring 2015    837    917      306      154         141.0        119.0
# 4   Summer 2015    187    191       49       49          91.0         21.0
# 5     Fall 2015    888    961      325      158         131.0        128.0
# 6   Spring 2016    853    875      312      162         131.0        118.0
# 7   Summer 2016    377    237       68       47          76.0         42.0
# 8     Fall 2016    854    914      322      143         138.0        122.0
# 9   Spring 2017    786    809      324      139         128.0        123.0
# 10  Summer 2017    147    158       68       41          75.0         20.0
# ...

# %%
international_students.to_csv('Data/international_students.csv', index=False)
